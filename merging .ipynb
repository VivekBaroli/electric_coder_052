# %%
import pandas as pd

# %%
df = pd.read_csv("Flipkart_sabkuch.csv")
df
# Out:
#       Unnamed: 0                                            Product    Price  \
# 0              0                    Apple iPhone 15 (Black, 128 GB)  ₹58,999
# 1              1                vivo T3x 5G (Crimson Bliss, 128 GB)  ₹14,499
# 2              2              vivo T3x 5G (Celestial Green, 128 GB)  ₹12,999
# 3              3                vivo T3x 5G (Crimson Bliss, 128 GB)  ₹12,999
# 4              4              vivo T3x 5G (Celestial Green, 128 GB)  ₹14,499
# ...          ...                                                ...      ...
# 8600        8600  Gilhot Alert AC 90V-1000V Voltage Alert Detect...     ₹360
# 8601        8601  CHESTON 500W + 5M Extension Wire I 13000 rpm D...     ₹759
# 8602        8602  Walkers WKCB31M1 4in1 25W Soldering Iron Machi...     ₹199
# 8603        8603          VISKO 111-Red Combination Screwdriver Set     ₹272
# 8604        8604  INGCO 20V Compact Brushless Impact Drill | Pow...   ₹5,996
#
# ...

# %%
df1 = pd.read_csv("Flipkart_sabkuch_1.csv")
df1
# Out:
#       Unnamed: 0                                            Product   Price  \
# 0              0  Boult Boost Hybrid ANC & ENC Mic, 65H Battery,...  ₹3,999
# 1              1  Boult W40 with Quad Mic ENC, 48H Battery Life,...  ₹1,299
# 2              2  boAt Rockerz 255 Pro+ with ASAP Charge and upt...  ₹1,098
# 3              3  boAt Airdopes 161/163 with ASAP Charge & 40 HR...    ₹899
# 4              4  boAt Airdopes 161/163 with ASAP Charge & 40 HR...    ₹899
# ...          ...                                                ...     ...
# 3995        3995       Castrol 4T 20W-50 Synthetic Blend Engine Oil    ₹435
# 3996        3996  MOTUL 7100 4T 10W-50Ester core 10W-50 100% Est...  ₹1,272
# 3997        3997  Anaisha LED Headlight for Royal Enfield Classi...  ₹1,199
# 3998        3998                ELV Car Mobile Holder for Dashboard    ₹349
# 3999        3999    GoMechanic 150 psi Tyre Air Pump for Car & Bike  ₹1,299
#
# ...

# %%
df2 = pd.read_csv("Flipkart_sabkuch_2.csv")
df2
# Out:
#       Unnamed: 0                                            Product   Price  \
# 0              0  DCS Pro FITNESS GYM KIT + 3Ft. (Straight + Ben...  ₹1,499
# 1              1  Shopeleven Multi-Functional Training Band, Bod...  ₹1,399
# 2              2  Oddish fitness combo Double spring Tummy Trimm...    ₹329
# 3              3  Proactive Sports & Fitness Wooden Rope with Ro...    ₹188
# 4              4  Reverie Retail GripGuard Spectacle Ear Hooks: ...    ₹190
# ...          ...                                                ...     ...
# 5315        5315  BOLDFIT Ankle Binder For Pain Relief Grip Gym ...    ₹299
# 5316        5316  BOLDFIT Ankle Support For Pain Relief Ankle Wr...    ₹349
# 5317        5317  AGEasy Comfort Knee Cap Anti-Slip with Cotton ...    ₹489
# 5318        5318  Nyamah sales No-Bounce Breast Support Belt Pos...    ₹219
# 5319        5319  Dee Fit High quality PVC 10kg Hexa Dumbbell ea...    ₹599
#
#      Original Price Discount  Rating Rating & reviews  \
# ...

# %%
df3 = pd.read_csv("Flipkart_sabkuch_3.csv")
df3
# Out:
#       Unnamed: 0                                            Product Price  \
# 0              0  Beyond Snack Kerala Banana Chips- 6 flavours C...  ₹437
# 1              1  Prolicious Bestseller Khakhra Combo | High Pro...  ₹525
# 2              2       JOLOCHIP Hottest CHIP Madness Last Challenge  ₹249
# 3              3                              Haldiram's Bhujia Sev   ₹78
# 4              4                               Haldiram's Moong Dal   ₹48
# ...          ...                                                ...   ...
# 8799        8799  NidraNari Magic-Water Coloring Book-Magic Wate...  ₹159
# 8800        8800  MTG Olympiad Prep-Guide Class 3 Science (NSO) ...  ₹200
# 8801        8801  Oswaal CBSE Question Bank Class 11 Economics, ...  ₹509
# 8802        8802                                Pride and Prejudice  ₹431
# 8803        8803                   All-Time Favourites for Children  ₹236
#
#      Original Price Discount  Rating Rating & reviews                Category  \
# ...

# %%
df4 = pd.read_csv("Flipkart_sabkuch_4.csv")
df4
# Out:
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 15493         15493       15493
# 15494         15494       15494
# 15495         15495       15495
# 15496         15496       15496
# 15497         15497       15497
#
#                                                  Product    Price  \
# 0      KURLON Dual Comfort Soft & Firm High Resilienc...   ₹7,699
# 1      KURLON Orthopedic 6 inch Queen Memory Foam Mat...   ₹8,739
# 2      Flipkart Perfect Homes Opus Engineered Wood Ki...  ₹13,799
# 3      Flipkart Perfect Homes Opus Engineered Wood Ki...  ₹13,799
# 4                        Attache PP Collapsible Wardrobe     ₹378
# ...                                                  ...      ...
# 15493  EssCubes Enterprise Baby Feeding Bowl with Lid...     ₹895
# ...

# %%
df6 = pd.read_csv("Flipkart_sabkuch_5.csv")
df6
# Out:
#        Unnamed: 0                                            Product   Price  \
# 0               0  Boult Drift+ Bluetooth Calling, 1.85" HD, 500N...  ₹1,399
# 1               1  Boult Drift BT Calling HD Display, 140+ Watchf...  ₹1,299
# 2               2  Fastrack Revoltt FS1 1.83 Display|BT Calling|F...  ₹1,099
# 3               3  Gamesir T800 BT watch 1.83" Screen Sunlight Pr...    ₹617
# 4               4  Fastrack Revoltt FS1|1.83 Display|BT Calling|F...  ₹1,099
# ...           ...                                                ...     ...
# 17343         994           Women Pure Cotton Kurta Pant Dupatta Set    ₹609
# 17344         995            Women Night Suit Set Light Blue Printed    ₹474
# 17345         996                  Printed Hand Batik Art Silk Saree    ₹264
# 17346         997               Women Full Sleeve Printed Sweatshirt    ₹329
# 17347         998        Women Full Sleeve Printed Hooded Sweatshirt    ₹449
#
# ...

# %%
df5 = pd.read_csv("Flipkart_sabkuch_6.csv")
df5
# Out:
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 12541         12541       12541
# 12542         12542       12542
# 12543         12543       12543
# 12544         12544       12544
# 12545         12545       12545
#
#                                                  Product Price Original Price  \
# 0      Oddish R SHAPE ADJUSTABLE SPRING COUNTER HAND ...  ₹180         ₹1,299
# 1      BoldFire Power Twister Bar - Upper Body Exerci...  ₹348           ₹999
# 2      BOLDFIT Mini Loop Band Heavy Bands Workout The...  ₹329           ₹399
# 3      BOLDFIT Heavy Resistance Band Set For Exercise...  ₹998         ₹1,499
# 4           Flexfoece Bodyshaper 11 in 1 Resistance Tube  ₹317         ₹1,474
# ...                                                  ...   ...            ...
# ...

# %%
df5 = df5.drop(["Unnamed: 0.1", "Unnamed: 0"] , axis=1) 
df5
# Out:
#                                                  Product Price Original Price  \
# 0      Oddish R SHAPE ADJUSTABLE SPRING COUNTER HAND ...  ₹180         ₹1,299
# 1      BoldFire Power Twister Bar - Upper Body Exerci...  ₹348           ₹999
# 2      BOLDFIT Mini Loop Band Heavy Bands Workout The...  ₹329           ₹399
# 3      BOLDFIT Heavy Resistance Band Set For Exercise...  ₹998         ₹1,499
# 4           Flexfoece Bodyshaper 11 in 1 Resistance Tube  ₹317         ₹1,474
# ...                                                  ...   ...            ...
# 12541           Harwat PETROL CAR ADDITIVE KIT Chain Oil  ₹399           ₹666
# 12542  Ambipur LAVENDER SPA CAR AIR FRESHENER STARTER...  ₹300           ₹349
# 12543                        Ambipur JASMINE, AQUA Spray  ₹618           ₹698
# 12544  WINKCART Ambi Pur Aqua Car Vent Air Freshener ...  ₹444           ₹599
# 12545             TENZ PETROL CAR ADDITIVE KIT Chain Oil  ₹399           ₹666
#
# ...

# %%
df6 = df6.drop("Unnamed: 0", axis=1 )
df6
# Out:
#                                                  Product   Price  \
# 0      Boult Drift+ Bluetooth Calling, 1.85" HD, 500N...  ₹1,399
# 1      Boult Drift BT Calling HD Display, 140+ Watchf...  ₹1,299
# 2      Fastrack Revoltt FS1 1.83 Display|BT Calling|F...  ₹1,099
# 3      Gamesir T800 BT watch 1.83" Screen Sunlight Pr...    ₹617
# 4      Fastrack Revoltt FS1|1.83 Display|BT Calling|F...  ₹1,099
# ...                                                  ...     ...
# 17343           Women Pure Cotton Kurta Pant Dupatta Set    ₹609
# 17344            Women Night Suit Set Light Blue Printed    ₹474
# 17345                  Printed Hand Batik Art Silk Saree    ₹264
# 17346               Women Full Sleeve Printed Sweatshirt    ₹329
# 17347        Women Full Sleeve Printed Hooded Sweatshirt    ₹449
#
#       Original Price Discount  Rating  Rating & reviews     Category  \
# 0             ₹8,499  83% off     NaN               NaN  Electronics
# ...

# %%
df4 = df4.drop(["Unnamed: 0.1", "Unnamed: 0"] , axis=1)

# %%
df4
# Out:
#                                                  Product    Price  \
# 0      KURLON Dual Comfort Soft & Firm High Resilienc...   ₹7,699
# 1      KURLON Orthopedic 6 inch Queen Memory Foam Mat...   ₹8,739
# 2      Flipkart Perfect Homes Opus Engineered Wood Ki...  ₹13,799
# 3      Flipkart Perfect Homes Opus Engineered Wood Ki...  ₹13,799
# 4                        Attache PP Collapsible Wardrobe     ₹378
# ...                                                  ...      ...
# 15493  EssCubes Enterprise Baby Feeding Bowl with Lid...     ₹895
# 15494  TINNY TOTS Baby Feeding Bottle Twin Handle Sip...     ₹474
# 15495                        Fulkiza Baby Bottle Cleaner     ₹949
# 15496  truecart care 3 pcs silicone Baby Milk Bottle ...     ₹439
# 15497  Uber World Plastic Waterproof Art Smock Kids P...     ₹649
#
#       Original Price Discount  Rating Rating & reviews  \
# 0             ₹9,999  23% off     4.1          (8,405)
# 1            ₹10,999  20% off     4.2          (2,751)
# ...

# %%
df3 = df3.drop("Unnamed: 0", axis=1 )
df3
# Out:
#                                                 Product Price Original Price  \
# 0     Beyond Snack Kerala Banana Chips- 6 flavours C...  ₹437           ₹540
# 1     Prolicious Bestseller Khakhra Combo | High Pro...  ₹525           ₹535
# 2          JOLOCHIP Hottest CHIP Madness Last Challenge  ₹249            NaN
# 3                                 Haldiram's Bhujia Sev   ₹78           ₹105
# 4                                  Haldiram's Moong Dal   ₹48            ₹60
# ...                                                 ...   ...            ...
# 8799  NidraNari Magic-Water Coloring Book-Magic Wate...  ₹159           ₹299
# 8800  MTG Olympiad Prep-Guide Class 3 Science (NSO) ...  ₹200            NaN
# 8801  Oswaal CBSE Question Bank Class 11 Economics, ...  ₹509           ₹599
# 8802                                Pride and Prejudice  ₹431           ₹599
# 8803                   All-Time Favourites for Children  ₹236           ₹250
#
# ...

# %%
df2 = df2.drop("Unnamed: 0", axis=1 )
df2
# Out:
#                                                 Product   Price  \
# 0     DCS Pro FITNESS GYM KIT + 3Ft. (Straight + Ben...  ₹1,499
# 1     Shopeleven Multi-Functional Training Band, Bod...  ₹1,399
# 2     Oddish fitness combo Double spring Tummy Trimm...    ₹329
# 3     Proactive Sports & Fitness Wooden Rope with Ro...    ₹188
# 4     Reverie Retail GripGuard Spectacle Ear Hooks: ...    ₹190
# ...                                                 ...     ...
# 5315  BOLDFIT Ankle Binder For Pain Relief Grip Gym ...    ₹299
# 5316  BOLDFIT Ankle Support For Pain Relief Ankle Wr...    ₹349
# 5317  AGEasy Comfort Knee Cap Anti-Slip with Cotton ...    ₹489
# 5318  Nyamah sales No-Bounce Breast Support Belt Pos...    ₹219
# 5319  Dee Fit High quality PVC 10kg Hexa Dumbbell ea...    ₹599
#
#      Original Price Discount  Rating Rating & reviews  \
# 0            ₹3,999  62% off     3.9             (15)
# 1            ₹2,999  53% off     NaN              NaN
# ...

# %%
df1 = df1.drop("Unnamed: 0", axis=1 )
df1
# Out:
#                                                 Product   Price  \
# 0     Boult Boost Hybrid ANC & ENC Mic, 65H Battery,...  ₹3,999
# 1     Boult W40 with Quad Mic ENC, 48H Battery Life,...  ₹1,299
# 2     boAt Rockerz 255 Pro+ with ASAP Charge and upt...  ₹1,098
# 3     boAt Airdopes 161/163 with ASAP Charge & 40 HR...    ₹899
# 4     boAt Airdopes 161/163 with ASAP Charge & 40 HR...    ₹899
# ...                                                 ...     ...
# 3995       Castrol 4T 20W-50 Synthetic Blend Engine Oil    ₹435
# 3996  MOTUL 7100 4T 10W-50Ester core 10W-50 100% Est...  ₹1,272
# 3997  Anaisha LED Headlight for Royal Enfield Classi...  ₹1,199
# 3998                ELV Car Mobile Holder for Dashboard    ₹349
# 3999    GoMechanic 150 psi Tyre Air Pump for Car & Bike  ₹1,299
#
#      Original Price Discount  Rating Rating & reviews     Category  \
# 0            ₹9,999  60% off     4.1            (164)  Electronics
# ...

# %%
df = df.drop("Unnamed: 0", axis=1 )
df
# Out:
#                                                 Product    Price  \
# 0                       Apple iPhone 15 (Black, 128 GB)  ₹58,999
# 1                   vivo T3x 5G (Crimson Bliss, 128 GB)  ₹14,499
# 2                 vivo T3x 5G (Celestial Green, 128 GB)  ₹12,999
# 3                   vivo T3x 5G (Crimson Bliss, 128 GB)  ₹12,999
# 4                 vivo T3x 5G (Celestial Green, 128 GB)  ₹14,499
# ...                                                 ...      ...
# 8600  Gilhot Alert AC 90V-1000V Voltage Alert Detect...     ₹360
# 8601  CHESTON 500W + 5M Extension Wire I 13000 rpm D...     ₹759
# 8602  Walkers WKCB31M1 4in1 25W Soldering Iron Machi...     ₹199
# 8603          VISKO 111-Red Combination Screwdriver Set     ₹272
# 8604  INGCO 20V Compact Brushless Impact Drill | Pow...   ₹5,996
#
#      Original Price Discount  Rating                   Rating & reviews  \
# 0           ₹69,900  15% off     4.6   2,10,909 Ratings & 7,387 Reviews
# ...

# %%
df_f = pd.concat([df,df1,df2,df3,df4,df5,df6], ignore_index=True)

len(df_f)
# Out:
# 72121

# %%
df_f.isnull().sum()
# Out:
# Product                 1
# Price                 321
# Original Price       3550
# Discount             3840
# Rating              31828
# Rating & reviews    31828
# Category                0
# Sub category            0
# brand                   1
# dtype: int64

# %%
df_f.to_csv("Flipkart_final_dataset.csv")
